# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
iteration = 100

# %%
LR_START = 1e-4
LR_END   = 1E-5
DECAY_RATE = 0.05

# %%
LR_REC = []
for i in range(iteration):
    LR = LR_END + (LR_START - LR_END)*np.exp(-DECAY_RATE*(i))
    LR_REC = np.append(LR_REC, LR)

# %%
plt.plot(range(iteration), LR_REC)

# %%
LR_START1 = 1e-4
LR_END1   = 1E-6
DECAY_RATE1 = 0.04
LR_REC1 = []
for i in range(iteration):
    LR1 = LR_END1 + (LR_START1 - LR_END1)*np.exp(-DECAY_RATE1*(i))
    LR_REC1 = np.append(LR_REC1, LR1)

# %%
plt.plot(range(iteration), LR_REC1)

# %%
plt.plot(range(iteration), LR_REC)
plt.plot(range(iteration), LR_REC1)
plt.show()

# %%
EPSILON = 1
EXPLORE_MAX = 1.0
EXPLORE_MIN = 0.005
DECAY_RATE = 0.1

# %%
EPSILON_REC = []
for i in range(iteration):
    EPSILON = 1-(EXPLORE_MIN + (EXPLORE_MAX - EXPLORE_MIN)*np.exp(-DECAY_RATE*i))
    EPSILON_REC = np.append(EPSILON_REC, EPSILON)

# %%
plt.plot(range(iteration), EPSILON_REC)

# %%
EPSILON_REC[-5:]
# Out:
# array([0.99492552, 0.99493261, 0.99493902, 0.99494483, 0.99495008])
